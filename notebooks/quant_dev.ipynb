# %%
from google.colab import drive
drive.mount('/content/drive')

# %%
# !pip install -e /content/drive/MyDrive/develop/Projects/ifunc-git --force-reinstall
# Out:
# Obtaining file:///content/drive/MyDrive/develop/Projects/ifunc-git
#   Installing build dependencies ... done
#   Checking if build backend supports build_editable ... done
#   Getting requirements to build editable ... done
#   Preparing editable metadata (pyproject.toml) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 183.8/183.8 kB 2.3 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 57.3/57.3 kB 4.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.6/6.6 MB 28.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 161.7/161.7 kB 12.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 807.9/807.9 kB 41.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 80.2/80.2 kB 5.2 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.2/3.2 MB 83.3 MB/s eta 0:00:00
# ...
#   Building editable for ifunc (pyproject.toml) ... done
# ...

# %%
# !pip install -e /content/drive/MyDrive/develop/Projects/quant-dev-git --force-reinstall
# Out:
# Obtaining file:///content/drive/MyDrive/develop/Projects/quant-dev-git
#   Installing build dependencies ... done
#   Checking if build backend supports build_editable ... done
#   Getting requirements to build editable ... done
#   Preparing editable metadata (pyproject.toml) ... done
# ...
#   Building editable for quant-dev (pyproject.toml) ... done
#   Created wheel for quant-dev: filename=quant_dev-0.1.0-0.editable-py3-none-any.whl size=1657 sha256=4bb8de962bd18b36fcdd332df051a1689dc36fa974c9e35ed26f0a0bc35a8626
#   Stored in directory: /tmp/pip-ephem-wheel-cache-6sjbzc9p/wheels/a1/df/15/6c7540a6a7c3da806998e93ed348df7e09784bb05f630bee70
# Successfully built quant-dev
# ...

# %%
import sys, os
#sys.path.append('/content/drive/MyDrive/develop/Projects/quant-dev-git/src')
print(os.getcwd())
os.chdir('/content/drive/MyDrive/develop/Projects/quant-dev-git')
# Out:
# /content/drive/MyDrive/develop/Projects/quant-dev-git

# %% [markdown]
# # Linux

# %%
# !mkdir -p src/quant_dev/data
# !touch src/quant_dev/data/manager.py

# %%
# %%writefile src/quant_dev/data/manager.py
# src/quant_dev/data/manager.py

import yfinance as yf
import pandas as pd
from pathlib import Path
from typing import Optional, List
from datetime import datetime, timedelta

class DataManager:
    def get_or_fetch(
        self,
        ticker: str,
        timeframe: str = "1d",
        days: int = 365,
        prepost: bool = False,
        auto_adjust: bool = True,
        force_download: bool = False,
    ) -> pd.DataFrame:
        """Get data from cache or download"""
        # 1. Check cache (CSV)
        cache_path = self.data_dir / f"{ticker}_{timeframe}.csv"
        if not force_download and cache_path.exists():
            df = pd.read_csv(cache_path, index_col=0, parse_dates=True)
            return self._normalize_index(df, timeframe)

        # 2. Download
        end = datetime.now()
        start = end - timedelta(days=days)
        df = yf.download(
            ticker, start=start, end=end,
            interval=timeframe, prepost=prepost, auto_adjust=auto_adjust,
            progress=False
        )

        # 3. Cache
        df.to_csv(cache_path)
        return self._normalize_index(df, timeframe)
# Out:
# Overwriting src/quant_dev/data/manager.py

# %% [markdown]
# # GitAction

# %%
from ifunc.utils.git_action import GitAction
git = GitAction(email='ipython168@gmail.com', name='ipython168')
git.deploy_ssh_key()
message = """move"""
# Out:
# 👤 設定 git user
# ✅ Git user 已設定為: ipython168 <ipython168@gmail.com>
# 🔧 步驟 1: 檢查同移動金鑰
# 📂 .ssh 目標位置: /content/drive/MyDrive/develop/.ssh
# total 1
# -rw------- 1 root root 411 Jan 23  2026 id_ed25519
# -rw------- 1 root root 102 Jan 23  2026 id_ed25519.pub
#
# ✅ 金鑰已移動到 ~/.ssh/
# 📋 步驟 2: 顯示公鑰
# ...
# ssh-ed25519 AAAAC3NzaC1lZDI1NTE5AAAAINaM6Y0MXgaNLq6n9Uq2C2XrPN7a4RqOhTsWYIUERFrd ipython168@gmail.com
# ...
# 🔐 步驟 3: 設定權限
# 🌐 步驟 4: 接受 GitHub 主機
# 🔗 步驟 5: 測試連線
# Hi ipython168-git! You've successfully authenticated, but GitHub does not provide shell access.
#
# ✅ 連線成功
#
# 📦 步驟 6: 檢查 Git Remote
# 當前目錄: /content/drive/MyDrive/develop/Projects/quant-dev-git
# ✅ 係一個 Git repository
#
# Remote URL:
# origin	git@github.com:ipython168-git/quant-dev-git.git (fetch)
# origin	git@github.com:ipython168-git/quant-dev-git.git (push)
#
# list branch:
# * main
#   remotes/origin/main

# %%
git.commit_add_all(commit_message=message)
git.push(branch='main')

# %% [markdown]
# # API **示例**
