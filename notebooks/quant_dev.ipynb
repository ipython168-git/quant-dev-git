# %%
from google.colab import drive
drive.mount('/content/drive')

# %%
# !python /content/drive/MyDrive/develop/Projects/ifunc-git/ifunc/setup_chrome_in_colab.py
# !pip install -e /content/drive/MyDrive/develop/Projects/ifunc-git --force-reinstall

# %%
# !pip install -e /content/drive/MyDrive/develop/Projects/quant-dev-git --force-reinstall

# %%
# !python -m ifunc.utils.backup

# %%
import sys, os
sys.path.append('/content/drive/MyDrive/develop/')
print(os.getcwd())
os.chdir('/content/drive/MyDrive/develop/Projects/quant-dev-git')
# Out:
# /content
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# /tmp/ipykernel_733/3594902388.py in <cell line: 0>()
#       2 sys.path.append('/content/drive/MyDrive/develop/')
#       3 print(os.getcwd())
# ----> 4 os.chdir('/content/drive/MyDrive/develop/Projects/quant-dev-git')
#
# FileNotFoundError: [Errno 2] No such file or directory: '/content/drive/MyDrive/develop/Projects/quant-dev-git'

# %%
from google.colab import drive
drive.mount('/content/drive')

# %%
from ifunc.utils.logging import setup_logging
setup_logging(config_path=None, tz_str='Asia/Hong_Kong')

# %% [markdown]
# # Linux

# %% [markdown]
# # GitAction

# %%
from ifunc.utils.git_action import GitAction
git = GitAction(email='ipython168@gmail.com', name='ipython168')
git.deploy_ssh_key()

# %%
# 第一次起壇時行呢格：
# !git init
# !git checkout -b main
REPO_URL = '在此貼上你的_SSH_URL'  # <--- 手動貼呢度
# !git remote add origin {REPO_URL}
# !git add .
# !git commit -m 'initial commit from starter'
# !git push -u origin main

# %%
git.check_before_push()

# %%
message = """update from colab"""
git.commit_add_all(commit_message=message)
git.push(branch='main')

# %% [markdown]
# # API 示例
